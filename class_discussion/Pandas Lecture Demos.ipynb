# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_1 = pd.DataFrame(np.array([[4,5,2],[3,6,9],[1,2,3]])), columns == ['a', 'b', 'c']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_1 = pd.DataFrame(np.array([[4,5,2],[3,6,9],[1,2,3]])), columns == ['a', 'b', 'c']
#
# NameError: name 'columns' is not defined

# %%
data_dictionary = {'Fruits' :['apples','pears'], 'Vegetables':['brocoli','potato']}
df_2 = pd.DataFrame(data = data_dictionary)
df_2
# Out:
#    Fruits Vegetables
# 0  apples    brocoli
# 1   pears     potato

# %%
df_titantic = pd.read_csv('titanic_data.csv')
df_titantic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titantic.loc[:, "Pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df_titantic.iloc[:,2]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
plt.figure()
plt.scatter(df_titantic.index, df_titantic.loc[:, "Age"])
plt.show()

# %%
p0 = [2, 0] # initial guess at parameters
