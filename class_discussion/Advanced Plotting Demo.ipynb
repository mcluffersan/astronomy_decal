# %%
#import statements
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x,y = np.meshgrid(np.linspace(-1,1,10), np.linspace(2,-2,10))
f = x * y

plt.figure()
plt.imshow(f, cmap = 'inferno', origin = 'lower')
plt.show()

# %%
x,y = np.meshgrid(np.linspace(-1,1,100), np.linspace(2,-2,100))
a = np.sqrt(x**2+y**2)

plt.figure()
plt.imshow(a)
plt.show()

# %%
#statistical plots
import seaborn as sns

# %%
#look at lecture video later
# penguin_data = sns

# %%
sns.barplot(data = penguins_data, x = 'island', y = 'body_mass_g')
